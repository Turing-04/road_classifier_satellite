# %%
import cv2
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# %%
# Set the figure size and create the subplots
fig, axes = plt.subplots(1, 3, figsize=(12,4))
fig.subplots_adjust(wspace=0.1, hspace=0.2)

for ax in axes:
    ax.axis('off')

axes[0].imshow(mpimg.imread('../test/test_1.png'))
axes[0].set_title('Satellite image')

axes[1].imshow(mpimg.imread('../results/test_1.png'))
axes[1].set_title('NN prediction')

img = cv2.imread('predictions/prediction_001.png')
axes[2].imshow(img, cmap="gray")
axes[2].set_title('After postprocessing')

# Show the plot
plt.show()

# %%
# Set the figure size and create the subplots
for i in range(1,5):
    fig, axes = plt.subplots(1, 3, figsize=(12,4))
    fig.subplots_adjust(wspace=0.1, hspace=0.2)

    for ax in axes:
        ax.axis('off')

    axes[0].imshow(mpimg.imread(f'../test/test_{i}.png'))
    axes[0].set_title('Satellite image')

    axes[1].imshow(mpimg.imread(f'../results/test_{i}.png'))
    axes[1].set_title('NN prediction')

    img = cv2.imread(f'predictions/prediction_00{i}.png')
    axes[2].imshow(img, cmap="gray")
    axes[2].set_title('After postprocessing')

    # Show the plot
    plt.show()

# %%
# Set the figure size and create the subplots
for i in range(1,5):
    fig, axes = plt.subplots(1, 3, figsize=(12,4))
    fig.subplots_adjust(wspace=0.1, hspace=0.2)

    for ax in axes:
        ax.axis('off')

    axes[0].imshow(mpimg.imread(f'../test/test_{i}.png'))
    axes[0].set_title('Satellite image')

    axes[1].imshow(mpimg.imread(f'../results/test_{i}.png'))
    axes[1].set_title('NN prediction')

    img = cv2.imread(f'predictions/prediction_00{i}.png')
    axes[2].imshow(img, cmap="gray")
    axes[2].set_title('After postprocessing')

    # Show the plot
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 3
#       1 # Set the figure size and create the subplots
#       2 for i in range(1,5):
# ----> 3     fig, axes = plt.subplots(1, 3, figsize=(12,4))
#       4     fig.subplots_adjust(wspace=0.1, hspace=0.2)
#       6     for ax in axes:
#
# NameError: name 'plt' is not defined

# %%
## Need to work on some nice visual stuff, graph and informations about our dataset !

# %%
# load the images from the "training" folder
images = load_images()

# print some information about the dataset
print('Total number of images:', images.shape[0])
print('Size of each image:', images.shape[1:])
print('Minimum pixel value:', np.min(images))
print('Maximum pixel value:', np.max(images))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [34], line 2
#       1 # load the images from the "training" folder
# ----> 2 images = load_images()
#       4 # print some information about the dataset
#       5 print('Total number of images:', images.shape[0])
#
# Cell In [33], line 3, in load_images(image_size)
#       1 def load_images(image_size=(64, 64)):
#       2     # get the list of image filenames
# ----> 3     filenames = os.listdir('training')
#       5     # create an empty array to store the images
#       6     images = np.zeros((len(filenames), image_size[0], image_size[1], 3), dtype=np.float32)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'training'
